# %% [markdown]
# Linux Komutları

# %% [markdown]
# Temel Komutlar

# %%
#dizin öğrenme
# !pwd
# Out:
# /home/denshn/Masaüstü/miul_course

# %%
#dizin içindeki bilgileri öğrenme
# !ls
# Out:
# Untitled-1.ipynb

# %%
# !ls --help
# Out:
# Kullanım: ls [SEÇENEK]... [DOSYA]...
# DOSYA'lar hakkında bilgi listele (öntanımlı olarak geçerli dizin).
# -cftuvSUX veya --sort belirtilmemişse girdileri abecesel olarak sırala.
#
# Uzun seçeneklere olan gerekli argümanlar kısa seçenekler için de geçerlidir.
#   -a, --all                  . ile başlayan girdileri yok sayma
#   -A, --almost-all           ima edilen . ve .. ögelerini listeleme
#       --author               -l ile her dosyanın yazarını yazdır
#   -b, --escape               grafik olmayan karakterler için C tarzı
#                                kaçışlar yazdır
#       --block-size=BOYUT     -l ile boyutları yazdırırken onları BOYUT kadar
#                                ölçeklendir; örn. '--block-size=M', aşağıda
#                                BOYUT biçimine bakın
#   -B, --ignore-backups       ~ ile biten ima edilen girdileri listeleme
#   -c                         -lt ile: ctime ile sırala ve göster (dosya durum
# ...

# %%
# !ls -l #izinler ile
# Out:
# toplam 4
# -rw-r--r-- 1 denshn denshn 984 Eki  7 14:27 Untitled-1.ipynb

# %%
# !ls -a #gizli dosyalar
# Out:
# .  ..  Untitled-1.ipynb

# %%
# !ls -a -l
# Out:
# toplam 12
# drwxr-xr-x 2 denshn denshn 4096 Eki  7 14:27 .
# drwxr-xr-x 5 denshn denshn 4096 Eki  7 14:26 ..
# -rw-r--r-- 1 denshn denshn  984 Eki  7 14:27 Untitled-1.ipynb

# %%
# !ls -r
# Out:
# Untitled-1.ipynb

# %%
# !ls -lh
# Out:
# toplam 4,0K
# -rw-r--r-- 1 denshn denshn 984 Eki  7 14:27 Untitled-1.ipynb

# %%
# %cd ..
# Out:
# /home/denshn/Masaüstü
# /home/denshn/.local/lib/python3.11/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !ls -l -h -a -r
# Out:
# toplam 1,1M
# -rwxr-xr-x  1 denshn denshn   681 Eyl 30 03:11  tr.org.pardus.mycomputer.desktop
# -rw-r--r--  1 denshn denshn 1015K Eki  7 12:42  React-HSD.odt
# drwxr-xr-x  6 denshn denshn  4,0K Eki  1 00:35  my-app2
# drwxr-xr-x  6 denshn denshn  4,0K Eki  1 00:36  my-app
# drwxr-xr-x  2 denshn denshn  4,0K Eki  7 14:27  miul_course
# -rw-r--r--  1 denshn denshn   147 Eki  1 00:43 'Metin Belgesi'
# drwx------ 21 denshn denshn  4,0K Eki  7 14:31  ..
# drwxr-xr-x  5 denshn denshn  4,0K Eki  7 14:26  .

# %%
# !ls -a
# Out:
#  .   'Metin Belgesi'   my-app	 React-HSD.odt
#  ..   miul_course      my-app2	 tr.org.pardus.mycomputer.desktop

# %%
# !ls -R
# Out:
# .:
# 'Metin Belgesi'   my-app    React-HSD.odt
#  miul_course	  my-app2   tr.org.pardus.mycomputer.desktop
#
# ./miul_course:
# Untitled-1.ipynb
#
# ./my-app:
# build  node_modules  package.json  package-lock.json  public  README.md  src
#
# ./my-app/build:
# asset-manifest.json  index.html   logo512.png	 robots.txt
# favicon.ico	     logo192.png  manifest.json  static
#
# ./my-app/build/static:
# css  js
#
# ./my-app/build/static/css:
# main.e6c13ad2.css  main.e6c13ad2.css.map
#
# ./my-app/build/static/js:
# 453.ed3810f9.chunk.js	   main.69e9ba7d.js		 main.69e9ba7d.js.map
# 453.ed3810f9.chunk.js.map  main.69e9ba7d.js.LICENSE.txt
#
# ./my-app/node_modules:
# abab
# accepts
# acorn
# acorn-globals
# acorn-import-attributes
# acorn-jsx
# acorn-walk
# address
# adjust-sourcemap-loader
# @adobe
# agent-base
# ajv
# ajv-formats
# ajv-keywords
# @alloc
# @ampproject
# ansi-escapes
# ansi-html
# ansi-html-community
# ansi-regex
# ansi-styles
# anymatch
# any-promise
# arg
# argparse
# ...

# %%
# !ls
# Out:
# 'Metin Belgesi'   my-app    React-HSD.odt
#  miul_course	  my-app2   tr.org.pardus.mycomputer.desktop

# %%
# %cd miul_course/
# Out:
# /home/denshn/Masaüstü/miul_course
# /home/denshn/.local/lib/python3.11/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !cd ..

# %%
# !pwd
# Out:
# /home/denshn/Masaüstü/miul_course

# %%
# %cd ~
# Out:
# /home/denshn
# /home/denshn/.local/lib/python3.11/site-packages/IPython/core/magics/osm.py:393: UserWarning: This is now an optional IPython functionality, using bookmarks requires you to install the `pickleshare` library.
#   bkms = self.shell.db.get('bookmarks', {})
# /home/denshn/.local/lib/python3.11/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# %cd /home/denshn/Masaüstü/miul_course
# Out:
# /home/denshn/Masaüstü/miul_course
# /home/denshn/.local/lib/python3.11/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !cd --help
# Out:
# cd: cd [-L|[-P [-e]] [-@]] [dizin]
#     Change the shell working directory.
#
#     Change the current directory to DIR.  The default DIR is the value of the
#     HOME shell variable. If DIR is "-", it is converted to $OLDPWD.
#
#     The variable CDPATH defines the search path for the directory containing
#     DIR.  Alternative directory names in CDPATH are separated by a colon (:).
#     A null directory name is the same as the current directory.  If DIR begins
#     with a slash (/), then CDPATH is not used.
#
#     If the directory is not found, and the shell option `cdable_vars' is set,
#     the word is assumed to be  a variable name.  If that variable has a value,
#     its value is used for DIR.
#
#     Options:
#       -L	force symbolic links to be followed: resolve symbolic
#     		links in DIR after processing instances of `..'
#       -P	use the physical directory structure without following
#     		symbolic links: resolve symbolic links in DIR before
# ...

# %%
# %cd --help
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 get_ipython().run_line_magic('cd', '--help')
#
# File ~/.local/lib/python3.11/site-packages/IPython/core/interactiveshell.py:2480, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2478     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2479 with self.builtin_trap:
# -> 2480     result = fn(*args, **kwargs)
#    2482 # The code below prevents the output from being displayed
#    2483 # when using magics with decorator @output_can_be_silenced
#    2484 # when the last Python token in the expression is a ';'.
#    2485 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/.local/lib/python3.11/site-packages/IPython/core/magics/osm.py:368, in OSMagics.cd(self, parameter_s)
#     365         ps = ent
#     366         break
# ...

# %%
# !ls
# Out:
# Untitled-1.ipynb

# %%
# !touch deneme

# %%
# !touch deneme.txt

# %%
# !ls
# Out:
# deneme	deneme.txt  Untitled-1.ipynb

# %%
# !mkdir test

# %%
# !mkdir test2 test3

# %%
# !ls
# Out:
# deneme	deneme.txt  test  test2  test3	Untitled-1.ipynb

# %%
# !mkdir {test4,test5}

# %%
# !ls
# Out:
# deneme	deneme.txt  test  test2  test3	test4  test5  Untitled-1.ipynb

# %%
# !mkdir -p test/first/second

# %%
# !mkdir test1/first/second
# Out:
# mkdir: `test1/first/second' dizini oluşturulamıyor: Böyle bir dosya ya da dizin yok

# %%
# !touch a.txt
# !touch b.txt

# %%
# !rm a.txt b.txt

# %%
# !touch b.txt

# %%
# !rm -i b.txt
# Out:
# rm: normal boş dosya 'b.txt' kaldırılsın mi? ^C

# %%
# !rm -f deneme

# %%
# !touch a.txt
# !touch b.txt

# %%
# !ls
# Out:
# a.txt  b.txt  deneme.txt  test	test2  test3  test4  test5  Untitled-1.ipynb

# %%
# %cd test
# Out:
# /home/denshn/Masaüstü/miul_course/test
# /home/denshn/.local/lib/python3.11/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !rm *
# Out:
# rm: 'first' silinemedi: Bir dizin

# %%
# !rm -r *

# %%
# !ls

# %%
# %cd ..
# Out:
# /home/denshn/Masaüstü/miul_course
# /home/denshn/.local/lib/python3.11/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !ls
# Out:
# a.txt  b.txt  deneme.txt  test	test2  test3  test4  test5  Untitled-1.ipynb

# %%
# !rmdir test

# %%
# !rmdir test3 -v
# Out:
# rmdir: dizin kaldırılıyor, 'test3'

# %%
# !rm -rf test4 #içi dolu dizini silme

# %%
# !cp a.txt test5/

# %%
# !cp -r test5 test2/

# %%
# !cp *.txt test2/

# %%
# !cp a.txt c.txt

# %%
# !ls
# Out:
# a.txt  b.txt  c.txt  deneme.txt  test2	test5  Untitled-1.ipynb

# %%
# !mv b.txt test2

# %%
# !mv test2 test5

# %%
# !ls
# Out:
# a.txt  c.txt  deneme.txt  test5  Untitled-1.ipynb

# %%
# !mv a.txt aa.txt

# %%
# !ls
# Out:
# aa.txt	c.txt  deneme.txt  test5  Untitled-1.ipynb

# %%
# !touch test.txt

# %%
# !cat test.txt

# %%
# !cat test.txt
# Out:
# deniz

# %%
# !cat > metin1.txt # metin yaz, üstüne yaz
# Out:
# ^C

# %%
# !cat >> metin1.txt # metin yaz, içinin sonuna yaz

# %%
# !cat metin1.txt aa.txt > metin3.txt #birleştir

# %%
# !cat <<EOF > metin4.txt #bunu görene kadar yaz
# Out:
# /bin/bash: satır 1: uyarı: bu belgede 1 satırında dosya sonu sonlandırılmış (istenen `EOF')

# %%
# !cat -n metin4.txt #satır görme

# %%
# !more #büyük dosyalar içindir
# Out:
# more: bad usage
# Try 'more --help' for more information.

# %%
# !ls
# Out:
# aa.txt	deneme.txt  metin3.txt	test5	  Untitled-1.ipynb
# c.txt	metin1.txt  metin4.txt	test.txt

# %%
# !more test.txt
# Out:
# deniz
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# (END)-

# %%
# !more -7 test.txt #ilk 7 satır
# Out:
# deniz
#
#
#
#
#
#
# (END)-

# %%
# !more +7 test.txt #ilk 7 satır
# Out:
# (END)-

# %%
# !more -s test.txt
# Out:
# deniz
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# (END)-

# %%
# !less #büyük dosyalar için
# Out:
# Missing filename ("less --help" for help)

# %%
# !less test.txt
# Out:
# deniz47h=
# test.txt (END)deniz
# ~
# ~
# ~
# ~
# ~
# ~
# ~
# ~
# ~
# ~
# ~
# ~
# ~
# ~
# ~
# ~
# ~
# ~
# ~
# ~
# ~
# ~
# (END)

# %%
# !tail #izlemek
# Out:
# ^C

# %%
# !ls
# Out:
# aa.txt	deneme.txt  metin3.txt	test5	  Untitled-1.ipynb
# c.txt	metin1.txt  metin4.txt	test.txt

# %%
# !tail test.txt
# Out:
# deniz

# %%
# !echo "Merhaba" #yazdır
# Out:
# Merhaba

# %%
# !echo "Hehho" > hello.txt #oluştur

# %%
# !ls
# Out:
# aa.txt	deneme.txt  metin1.txt	metin4.txt  test.txt
# c.txt	hello.txt   metin3.txt	test5	    Untitled-1.ipynb

# %%
# !echo "d" > hello.txt #üzerine yaz

# %%
# !echo "ff" >> hello.txt #içine ekle

# %%
# !echo +((25*3))
# Out:
# /bin/bash: -c: satır 1: beklenmeyen jeton `(' yakınında sözdizim hatası
# /bin/bash: -c: satır 1: `echo +((25*3))'

# %%
# !echo merhaba
# Out:
# merhaba

# %%
# !echo -e KDE '\n' d '\t' hepsi
# Out:
# KDE
#  d 	 hepsi

# %%
# !echo ~
# Out:
# /home/denshn

# %%
# !echo {1..5}
# Out:
# 1 2 3 4 5

# %%
# !arg="Linux"

# %%
# !echo $arg

# %%
# !echo $USER
# Out:
# denshn

# %%
# !env
# Out:
# SHELL=/bin/bash
# SESSION_MANAGER=local/pardus-nirvana-nb-s500-silver:@/tmp/.ICE-unix/1859,unix/pardus-nirvana-nb-s500-silver:/tmp/.ICE-unix/1859
# QT_ACCESSIBILITY=1
# PYTHONUNBUFFERED=1
# XDG_MENU_PREFIX=gnome-
# GNOME_DESKTOP_SESSION_ID=this-is-deprecated
# SSH_AUTH_SOCK=/run/user/1000/keyring/ssh
# PYTHON_FROZEN_MODULES=on
# ELECTRON_RUN_AS_NODE=1
# XMODIFIERS=@im=ibus
# DESKTOP_SESSION=gnome
# SSH_AGENT_PID=1817
# VSCODE_AMD_ENTRYPOINT=vs/workbench/api/node/extensionHostProcess
# GTK_MODULES=gail:atk-bridge
# PWD=/home/denshn/Masaüstü/miul_course
# XDG_SESSION_DESKTOP=gnome
# LOGNAME=denshn
# XDG_SESSION_TYPE=x11
# GPG_AGENT_INFO=/run/user/1000/gnupg/S.gpg-agent:0:1
# SYSTEMD_EXEC_PID=1876
# PYDEVD_IPYTHON_COMPATIBLE_DEBUGGING=1
# VSCODE_CODE_CACHE_PATH=/home/denshn/.config/Code/CachedData/38c31bc77e0dd6ae88a4e9cc93428cc27a56ba40
# _=/bin/env
# XAUTHORITY=/run/user/1000/gdm/Xauthority
# GJS_DEBUG_TOPICS=JS ERROR;JS LOG
# WINDOWPATH=2
# GDM_LANG=tr_TR.UTF-8
# HOME=/home/denshn
# ...

# %%
#shutdown
#shutdown -c 
#shutdown 12:50
#shutdown +5
#shutdown
#shutdown -h 
#shutdown -r 12:55
#reboot

# %%
# !hostname
# Out:
# pardus-nirvana-nb-s500-silver

# %%
# !date
# Out:
# Pzt 07 Eki 2024 15:17:44 +03

# %%
# !date --date="10 month ago"
# Out:
# Prş 07 Ara 2023 15:19:56 +03

# %%
# !date "+%d"
# Out:
# 07

# %%
# !date "+%D"
# Out:
# 10/07/24

# %%
# !history

# %%
# %history
# Out:
# !pip3 install ipykernel
# !pwd
# #dizin içindeki bilgileri öğrenme
# !ls
# !ls --help
# !ls -l
# !ls -a #gizli dosyalar
# !ls -a -l
# !ls -r
# !ls -lh
# !cd ..
# !ls -l -h -a -r
# !ls -a
# !ls -R
# %cd ..
# !ls -l -h -a -r
# !ls -a
# !ls -R
# !cd /Masaüstü
# !ls
# !cd miul_course/
# !cd ..
# !pwd
# %cd miul_course/
# !cd ..
# !pwd
# !cd ~
# %cd ~
# %cd /home/denshn/Masaüstü/miul_course
# !cd --help
# %cd --help
# !ls
# !touch deneme
# !touch deneme.txt
# !ls
# !mkdir test
# !mkdir test2 test3
# !ls
# !mkdir {test4,test5}
# !ls
# !mkdir test/first/second
# !mkdir -p test/first/second
# !mkdir test1/first/second
# !tocuh a.txt
# !tocuh b.txt
# !touch a.txt
# !touch b.txt
# !rm a.txt b.txt
# !touch b.txt
# !rm -i b.txt
# !rm -f deneme
# !touch a.txt
# !touch b.txt
# !ls
# %cd test
# !rm *
# !rm -r *
# !ls
# %cd ..
# !ls
# !rmdir test
# !rmdir test3 -v
# !rm -rf test4 #içi dolu dizini silme
# !cp a.txt test5/
# !cp -r test5 test2/
# !cp *.txt test2/
# !cp a.txt c.txt
# !ls
# ...

# %%
# !history | grep mkdir

# %%
# !history -c

# %%
# %history
# Out:
# !pip3 install ipykernel
# !pwd
# #dizin içindeki bilgileri öğrenme
# !ls
# !ls --help
# !ls -l
# !ls -a #gizli dosyalar
# !ls -a -l
# !ls -r
# !ls -lh
# !cd ..
# !ls -l -h -a -r
# !ls -a
# !ls -R
# %cd ..
# !ls -l -h -a -r
# !ls -a
# !ls -R
# !cd /Masaüstü
# !ls
# !cd miul_course/
# !cd ..
# !pwd
# %cd miul_course/
# !cd ..
# !pwd
# !cd ~
# %cd ~
# %cd /home/denshn/Masaüstü/miul_course
# !cd --help
# %cd --help
# !ls
# !touch deneme
# !touch deneme.txt
# !ls
# !mkdir test
# !mkdir test2 test3
# !ls
# !mkdir {test4,test5}
# !ls
# !mkdir test/first/second
# !mkdir -p test/first/second
# !mkdir test1/first/second
# !tocuh a.txt
# !tocuh b.txt
# !touch a.txt
# !touch b.txt
# !rm a.txt b.txt
# !touch b.txt
# !rm -i b.txt
# !rm -f deneme
# !touch a.txt
# !touch b.txt
# !ls
# %cd test
# !rm *
# !rm -r *
# !ls
# %cd ..
# !ls
# !rmdir test
# !rmdir test3 -v
# !rm -rf test4 #içi dolu dizini silme
# !cp a.txt test5/
# !cp -r test5 test2/
# !cp *.txt test2/
# !cp a.txt c.txt
# !ls
# ...

# %%
# !clear

# %%
# !reset
# Out:
# >78
